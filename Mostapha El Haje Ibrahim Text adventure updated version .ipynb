# %%
print("""
Docstring
Introduction:
In this game you will be playing as Jerry the character from Tom and Jerry the 
cartoon and you decide how to act in each situation as if you were Jerry and  
had to either plan a attack on Tom as payback to what Tom has done to you or 
to just plan an attack on Tom for fun. The stages in this game are going to be 
in the house Tom and Jerry live in. The purpose of this game is to make you feel as if you are
Jerry the mouse and attacking Tom most of the time, hope you enjoy playing this game.
Note some of the scenes are made up by me but based on Tom and Jerry the cartoon
""")
# importing necessary packages
import random
# importing this function to help player exit the game
from sys import exit 
# customizing the player experience in order to make it feel more real 
print("Welcome to a day of life of Jerry the mouse")
# asking the player what his name is 
name=input(prompt="What is your name? ").capitalize()
print(f"""
From now on {name} you will be Jerry in this game
""")
# defining the fail function 
# creating a function that helps player restart when they loose in the final round 
def fail():
    replay = input(prompt = """
Play again?
1. Yes
2. No
\n""")
    # conditional statement based on user choice
    if "1" in replay or "Y" in replay or "y" in replay:
        stg1()
    # conditional statement based on user choice
    elif "2" in replay or "N" in replay or "n" in replay:
        print("Game over, Thanks for playing")
    # conditional statement based on user choice
    else: 
        print("Error, please re-enter your choice")
        input(prompt='<Press enter to continue>')
        fail()
# defining stage 1  
def stg1():
    print("Welcome to level 1!\n")
    print("""
      You just woke up from your nest and found out that Tom has been putting 
      mice traps all morning from your nest to the kitchen in order to catch you
      \n""")
    input(prompt='<Press enter to continue>')
    print("""
    After finding out what Tom's plan was you now have to plan an attack, and you 
    eventually come up with two ideas 
    \n""")
    input(prompt='<Press enter to continue>')
    # defining payback_idea_1
    payback_idea_1=input(prompt= """The first idea is to put Tom's tail in one of the mice traps that you found in the kitchen?
    1. Go for it  
    2. Not enough
    3. Dont do anything
    \n""").lower()
    # conditional statement based on user choice
    if  "g" in payback_idea_1 or "1" in payback_idea_1 or "f" in payback_idea_1 or "i" in payback_idea_1:
        print("pick a better choice, like the second answer")
        stg1()
    # conditional statement based on user choice
    elif "e" in payback_idea_1 or "n" in payback_idea_1 or "2" in payback_idea_1:
        stg2()
    # conditional statement based on user choice
    elif "d" in payback_idea_1 or "3" in payback_idea_1 or "a" in payback_idea_1:
    # declaring objects
        number = random.randint(1,3) # random number remains the same for each guess
        chances = 3
    # looping until a user is out of guesses
    while int(chances) > 0:
        choice = input(prompt = "\n What is your guess (1-3)?\n")
        # converting choice for numerical comparison
        choice = int(choice)
        # conditional statement based on user choice
        if choice == number:
            print("Correct choice, on to the next level")
            stg3()
    # conditional statement based on user choice
    else:
        print("Error, please re-enter your choice")
        input(prompt='<Press enter to continue>')
        stg1()
    
    input(prompt="Try answering again? ")
# defining stage 2 
def stg2():
    input(prompt='<Press any key to continue>\n')
    # defining payback_idea_2
    payback_idea_2=input(prompt="""
    The second idea is to wait for the right time when Tom is eating to shoot him with you're crossbow? 
    1. Sounds cool
    2. Leave him 
    3. Whatever  
    \n""").lower()
    # conditional statement based on user choice
    if "s" in payback_idea_2 or "c" in payback_idea_2 or "1" in payback_idea_2:
        print("""
        This is a better way to take back you're revenge
        \n""")
        # defining an object 
        count = 4
        # creating a while loop which makes the game more interactive
        while count > 0:
            #print(count)
            count = count - 1
            print("you hear Tom eating now is the time for revenge")
            count = count -1 
            input(prompt="< Press ENTER to continue. >\n")
            print("you're going closer")
            count=count-1
            input(prompt="< Press ENTER to continue. >\n")
            print("you start aiming")
            count=count-1
            input(prompt="< Press ENTER to continue. >\n")
            print("you have a clear view")
            input(prompt="< Press ENTER to continue. >\n")

            print("Bullseye you just shot Tom on his hand, well done! Tom is injured ")
            print("Now to level 2!\n")
            stg3()
    # conditional statement based on user choice        
    elif "l" in payback_idea_2 or "h" in payback_idea_2 or "2" in payback_idea_2:
        stg2()
    # conditional statement based on user choice
    elif "w" in payback_idea_2 or "3" in payback_idea_2 or "e" in payback_idea_2:
    # declaring objects
        number = random.randint(1,3) # random number remains the same for each guess
        chances = 3
    # looping until a user is out of guesses
    while int(chances) > 0:
        choice = input(prompt = "\n What is your guess (1-3)?\n")
        # converting choice for numerical comparison
        choice = int(choice)
        # conditional statement based on user choice
        if choice == number:
            print("Correct guess, but you're being to sweet and you will need to start the game from the beginning")
            stg1()
    # conditional statement based on user choice
    else:
        input(prompt='<Press enter to continue>')
        stg2()
        
# defining stage 3
def stg3():
    print("""
    while walking in the garden you find Tom sleeping on the bench you want to decide 
    to either throw at him water to wake him up or just let him enjoy his nap
          """)
    input(prompt='<Press enter to continue>')
    # defining an ambush attack on Tom 
    attacking_tom=input(prompt="""
Go and grab a bucket of water and throw it on Tom to wake him up? 
1. Sure
2. Noooo
3. Dont know
\n""").lower()
    # conditional statement based on user choice
    if "s" in attacking_tom or "1" in attacking_tom or "u" in attacking_tom or "e" in attacking_tom or "r" in attacking_tom:
        print("Great thinking, now its time to become friends again with Tom")
        stg4()
    
    # conditional statement based on user choice
    elif "n" in attacking_tom or "2" in attacking_tom or "o" in attacking_tom:
        print('You should think again')
        stg3()
    # conditional statement based on user choice
    elif "d" in attacking_tom or "3" in attacking_tom or "k" in attacking_tom:
    # declaring objects
        number = random.randint(1,4) # random number remains the same for each guess
        chances = 4
    # looping until a user is out of guesses
    while int(chances) > 0:
        choice = input(prompt = "\n What is your guess (1-4)?\n")
        # converting choice for numerical comparison
        choice = int(choice)
        # conditional statement based on user choice
        if choice == number:
            print("Correct guess, but you're being to sweet to Tom")
            stg3()
    # conditional statement based on user choice
    else:
        print("Error, please re-enter your choice")
        input(prompt='<Press enter to continue>')
        stg3()
# defining stage 4 
def stg4():
    print("""
    After throwing the water bucket on Tom, you realize its time for peace and 
    you decide to cook dinner for Tom and you
    """)
    input(prompt='<Press enter to continue>')

    print("""
    While eating dinner Tom throws a pie at you as payback. So you end up stabbing Tom with 
    a fork on his bum
    """)
    input(prompt='<Press enter to continue>')
    print("""
    After fighting all day its time for you to pick if you want to continue the fighting today 
    by taking a left and going to the garden to bring your stick and beat up Tom or taking a right 
    and going back to your nest and calling it a day or just bringing Tom a cake by guessing Tom's
    favorite number between 1 and 5 and end the dinner 
    in a pleasent way 
    """)
    input(prompt='<Press enter to continue>')
    # defining final attack on Tom
    final_attack=input(prompt="""
Do you want to take a left to grab the stick and continue fighting or 
you want to take a right and return to you're nest and call it a day
or bring Tom a cake and end the evening peacefully?
1. Right 
2. Left
3. Get cake 
""").lower()
    # conditional statement based on user choice
    if "R" in final_attack or "1" in final_attack or "r" in final_attack:
        print('Well done, enough harm has been done and you should rest')
        input(prompt='<Press enter to continue>')
        print("""
   _____  ____   _   _   _____  _____          _______  _____         
  / ____|/ __ \ | \ | | / ____||  __ \     /\ |__   __|/ ____|        
 | |    | |  | ||  \| || |  __ | |__) |   /  \   | |  | (___          
 | |    | |  | || . ` || | |_ ||  _  /   / /\ \  | |   \___ \         
 | |____| |__| || |\  || |__| || | \ \  / ____ \ | |   ____) |        
  \_____|\____/ |_| \_| \_____||_|  \_\/_/    \_\|_|  |_____/         
   _____            __  __  ______    ____ __      __ ______  _____   
  / ____|    /\    |  \/  ||  ____|  / __ \\ \    / /|  ____||  __ \  
 | |  __    /  \   | \  / || |__    | |  | |\ \  / / | |__   | |__) | 
 | | |_ |  / /\ \  | |\/| ||  __|   | |  | | \ \/ /  |  __|  |  _  /  
 | |__| | / ____ \ | |  | || |____  | |__| |  \  /   | |____ | | \ \  
  \_____|/_/    \_\|_|  |_||______|  \____/    \/    |______||_|  \_\ 
  """)
        exit()
    elif "L" in final_attack or "2" in final_attack or "l" in final_attack:
        print ('Enough fighting, try answering again')
        fail()
    elif "c" in final_attack or "3" in final_attack or "g" in final_attack:
    # declaring objects
        number = random.randint(1,5) # random number remains the same for each guess
        chances = 5
    # looping until a user is out of guesses
    while int(chances) > 0:
        choice = input(prompt = "\n What is your guess (1-5)?\n")
        # converting choice for numerical comparison
        choice = int(choice)
        # conditional statement based on user choice
        if choice == number:
            print("You win!")
            print("GAME OVER")
            exit()
            break
        # conditional statement based on user choice
        elif choice != number:
            chances -= 1 
            if chances > 0:
                print(f"Wrong answer. You have {chances} guesses remaining.")
        # conditional statement based on user choice       
        elif chances == 0:
            print(f"You are out of guesses. The number was {number}.")
            stg1()
        # setting a different error message for inner and outer loops
        else:
            print("\nSomething went wrong.")
            stg4()
    # conditional statement based on user choice      
    else:
        print("Error, please re-enter your choice")
        input(prompt='<Press enter to continue>')
        stg4() 
stg1()
# Out:
# Docstring
# Introduction:
# In this game you will be playing as Jerry the character from Tom and Jerry the
# cartoon and you decide how to act in each situation as if you were Jerry and
# had to either plan a attack on Tom as payback to what Tom has done to you or
# to just plan an attack on Tom for fun. The stages in this game are going to be
# in the house Tom and Jerry live in. The purpose of this game is to make you feel as if you are
# Jerry the mouse and attacking Tom most of the time, hope you enjoy playing this game.
# Note some of the scenes are made up by me but based on Tom and Jerry the cartoon
#
# Welcome to a day of life of Jerry the mouse
